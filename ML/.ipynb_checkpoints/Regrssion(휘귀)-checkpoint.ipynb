# %% [markdown]
# #### 회귀 분석은 둘 이상의 변수 간의 관계를 보여주는 통계적 방법입니다. 일반적으로 그래프로 표현되는 이 방법은 종속 변수와 독립 변수 간의 관계를 테스트합니다. 일반적으로 독립 변수는 종속 변수에 따라 변경되며 회귀 분석은 해당 변경에서 가장 중요한 요소에 대한 답을 찾으려고 시도

# %% [markdown]
# ![%EC%BA%A1%EC%B2%98.PNG](attachment:%EC%BA%A1%EC%B2%98.PNG)

# %% [markdown]
# Y = 예측값
# W = 모델계수 / feature wights
# b = 편중항 / 절편
