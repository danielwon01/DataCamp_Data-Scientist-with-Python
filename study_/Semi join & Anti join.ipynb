# %% [markdown]
# # Semi join
# > 왼쪽테이블을 오른쪽 테이블에 일치하는 관측치로 필터링
#
# # Anti join
# > 오른쪽 테이블에 일치하는 관찰값이 없는 왼쪽 테이블의 관찰값을 반환 (왼쪽테이블의 열만 반환)

# %%
from IPython.display import Image
Image("semi_anti.png")

# %% [markdown]
# ### Semi join
#
# > 결과는 inner 조인과 같지만 Semi은 왼쪽테이블의 열만 표시
#   df2 = df.merge(df1,on = " " )

# %%
# Datacamp에 있는 자료 사용
tracks_invoices = non_mus_tcks.merge(top_invoices, on ="tid") # inner join과 같은 방식

# %% [markdown]
# ### Anti join
# df2 = df.merge(df1 , on = " " , how ='left')

# %%
# Datacamp에 있는 자료 사용
empl_cust = employees.merge(top_cust, on="srid",        
                            how='left', indicator=True)   # indicator = True는 _merge라는 새로운 열 추가

# %%
srid  lname_x fname_x                title  hire_date  ...    lname_y               phone                 fax               email_y     _merge
0     1    Adams  Andrew      General Manager 2002-08-14  ...        NaN                 NaN                 NaN                   NaN  left_only
1     2  Edwards   Nancy        Sales Manager 2002-05-01  ...        NaN                 NaN                 NaN                   NaN  left_only
2     3  Peacock    Jane  Sales Support Agent 2002-04-01  ...  Gonçalves  +55 (12) 3923-5555  +55 (12) 3923-5566  luisg@embraer.com.br       b
