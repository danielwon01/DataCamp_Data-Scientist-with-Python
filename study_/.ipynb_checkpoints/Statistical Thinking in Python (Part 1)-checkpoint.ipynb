# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings(action='ignore')

# %%
df = pd.read_csv('2008_swing_states.csv')
df.head()
# Out:
#   state           county  total_votes  dem_votes  rep_votes  dem_share
# 0    PA      Erie County       127691      75775      50351      60.08
# 1    PA  Bradford County        25787      10306      15057      40.64
# 2    PA     Tioga County        17984       6390      11326      36.07
# 3    PA    McKean County        15947       6465       9224      41.21
# 4    PA    Potter County         7507       2300       5109      31.04

# %%
# seaborn 스타일은 default 
sns.set()

# %%
_ = plt.hist(df['dem_share'])

# %%
n_data = len(set(df['dem_share']))
n_bins = np.sqrt(n_data)
n_bins = int(n_bins)
_ = plt.hist(df['dem_share'] , bins = n_bins)
plt.show()

# %%
# Binning bias  - 두가지 다른 bin 선택에 따라 플롯 해석을 다르게 하는 것 
# 히스토그램의 문제를 보완하기 위해 Bee swarm plot 사용 
# y축은 정량적 정보 , x 축에 데이터가 분산되어 있지만 x축에 따른 정확한 위치는 중요치 않다.

_ = sns.swarmplot(x='state', y='dem_share', data=df)
_ = plt.xlabel('state')
_ = plt.ylabel('percentage of votes for obama')
plt.show()

# %%
# Bee swarmplot 은 모든 점을 맞추는 데 데이터가 겹쳐서 표현되는 문제점이 있다.
# 위의 경우 ECDF (Empirical cumulative distribution function) 경험적 누적분포 사용

x =  np.sort(df['dem_share']) # X축 정렬 
y = np.arange(1, len(x) + 1 ) / len(x)  # Y축은 최대 1개의 균일한 간격의 데이터 포인트 

_ = plt.plot(x, y, marker='.', linestyle='none')
_ = plt.ylabel('ECDF')
_ = plt.xlabel('percentage of votes for obama')
plt.margins(0.02) #keeps data off plot edges
plt.show()

# %%
# ECDF 생성 함수 
def ecdf(data):
   
    # Number of data points: n
    n=len(data)
    # x-data for the ECDF: x
    x=np.sort(data)
    # y-data for the ECDF: y
    y = np.arange(1,n+1) / n
    return x, y

# %%
# 함수 사용 
x ,y = ecdf(df['dem_share'])
plt.plot(x , y , marker = '.' ,linestyle = 'none')
plt.ylabel('ECDF')
plt.xlabel('percentage of votes for obama')
plt.show()

# %% [markdown]
# ### the sample mean and median

# %%
# 평균은 이상치에 영향을 많이 받는다. 
# 이상치란 값이 나머지 대부분의 데이터보다 휠씬 크거나 작은 데이터 
np.mean(df)
# Out:
# total_votes    90424.513514
# dem_votes      47214.283784
# rep_votes      42236.567568
# dem_share         43.764414
# dtype: float64

# %%
# 중앙값은 데이터셋의 중간 값으로 이상치에 영향을 덜 받는다.
# 정렬된 데이터의 순위에 파생되는 것이 아니라 순위에서 파생 
np.median(df['dem_share'])
# Out:
# 43.185

# %% [markdown]
# ### Percentiles, outliers, and box plots

# %%
percentiles = np.percentile(df['dem_share'], [25 ,50 ,75, 95])
percentiles
# Out:
# array([37.3025, 43.185 , 49.925 , 60.8955])

# %%
sns.boxplot(df['state'] , df['dem_share'])
plt.show()

# %% [markdown]
# ### Variance and standard deviation

# %%
# 분산은 평균에서 거리를 제곱한 다음 이 모든 값의 평균
# 분산으로부터 분포가 얼마나 퍼져있는 파악 
np.var(df['dem_share'])
# Out:
# 114.24649492735986

# %%
# 표준편차 분산의 제곱근
# 데이터의 일반적인 확산에 대한 합리적인 판단 지표
np.std(df['dem_share'])
# Out:
# 10.68861520157592

# %%
np.sqrt(np.var(df['dem_share']))
# Out:
# 10.68861520157592

# %% [markdown]
# ### Covariance and the Pearson correlation coefficient

# %%
#scatter plot
plt.plot(df['total_votes']/1000, df['dem_share'], marker='.', linestyle='none')
plt.xlabel('votes (thousands)')
plt.ylabel('percentage of votes for obama')
plt.show()

# %%
# 2개의 확률변수의 선형 관계를 나타내는 값이다. 만약 2개의 변수중 하나의 값이 상승하는 경향을 보일 때 다른 값도 상승하는 선형 상관성이 있다면 양수의 공분산을 가진다.
# 각 확률변수들이 어떻게 퍼져있는지 파악 
# x의 편차와  y의 편차를 곱한것의 평균 

# x 및 y의 표준편차로 공분산을 나눈 것이 person correlation 데이터의 변동성을 비교한것 
# independant variability / variability due to codependence
# 무차원이며 -1 ~ 1 의 값을 갖는다. 


covariance_matrix = np.cov(df['total_votes'], df['dem_votes'])
np.round(covariance_matrix,0)
# Out:
# array([[2.02451039e+10, 1.24375502e+10],
#        [1.24375502e+10, 7.90553527e+09]])

# %%
def person_r (x, y) :
    
    corr_mat = np.corrcoef(x , y)
    return corr_mat[0,1]
r = person_r (df['total_votes'] ,df['dem_votes'])
r
# Out:
# 0.9831260443086195

# %% [markdown]
# ### Thinking Probabilistically-- Discrete Variables

# %%
#### Random number generators and hacker statistics

# 동일한 시드는 동일한 난수 시퀀스를 제공, "Sudo random generation"이라는 이름이 지정 ,재현가능한 코드를 위해 시드 설정
np.random.seed(42)
random_num = np.random.random(size = 4)
random_num
# Out:
# array([0.37454012, 0.95071431, 0.73199394, 0.59865848])

# %%
heads = random_num < 0.5
heads
# Out:
# array([ True, False, False, False])

# %%
np.sum(heads)
# Out:
# 1

# %%
# 4개의 동전이 모두 앞면이 나올 확률 

n_all_heads = 0

for _ in range(10000) :
    heads = np.random.random(size =4) < 0.5
    n_heads = np.sum(heads)
    
    if n_heads  == 4 :
        n_all_heads +=1

n_all_heads / 10000
# Out:
# 0.0619

# %%
# Bernoulli trial

def perform_bernoulli_trials(n, p):
  
    # Initialize number of successes: n_success
    n_success = 0

    # Perform trials
    for i in range(n):
        # Choose random number between zero and one: random_number
        random_number = np.random.random()

        # If less than p, it's a success so add one to n_success
        if random_number < p:
            n_success += 1

    return n_success

print(perform_bernoulli_trials(10000,0.5))
# Out:
# 5061

# %%
np.random.seed(42)
n_defaults = np.empty(1000)

for i in range(1000):
    n_defaults[i] = perform_bernoulli_trials(100,0.05)

_ = plt.hist(n_defaults)
_ = plt.xlabel('number of defaults out of 100 loans')
_ = plt.ylabel('probability')

plt.show()

# %%
x,y = ecdf(n_defaults)

_ = plt.plot(x,y, marker = '.', linestyle = 'none')
_ = plt.xlabel('x')
_ = plt.ylabel('y')

plt.show()

# Compute the number of 100-loan simulations with 10 or more defaults: n_lose_money
n_lose_money = np.sum(n_defaults >= 10)

# Compute and print probability of losing money
print('Probability of losing money =', n_lose_money / len(n_defaults))
# Out:
# Probability of losing money = 0.022

# %% [markdown]
# ### Probability distributions and stories

# %% [markdown]
# PMF 확률질량함수는 개별 결과의 확률 집합으로 정의
# n의 성공횟수 r은 성공확률이 p인 베르누이 시행은 이항분포

# %%
# Binomial distribution
np.random.binomial(4, 0.5)
# Out:
# 2

# %%
np.random.binomial(4 , 0.5 , size = 10) # size를 통해 이항 분포에서 샘플링할 난수 수를 함수로 지정
# Out:
# array([3, 3, 2, 2, 0, 3, 1, 2, 1, 2])

# %%
sample = np.random.binomial(60, 0.1, size = 10000)
n = 60
p = 0.1

# %%
# Binomial CDF 
sns.set()
x ,y = ecdf(sample)
_ = plt.plot(x ,y , marker = '.' , linestyle = 'none')
plt.margins(0.02)
_ = plt.xlabel('num of successes')
_ = plt.ylabel('CDF')
plt.show()

# %%
#Binomial PDF

n_defaults = np.random.binomial(100 , 0.05 , size = 10000)

bins = np.arange(min(n_defaults), max(n_defaults) + 1.5) - 0.5
_ = plt.hist(n_defaults, bins=bins)
_ = plt.margins(0.02)

_ = plt.xlabel('x')
_ = plt.ylabel('y')
plt.show()

# %% [markdown]
# ### Poisson processes and the Poisson distribution

# %% [markdown]
# 다음 사건이 일어날 타이밍은 이전 사건과 발생한 시간과 완전히 독립적
# 단위 시간 안에 어떤 사건이 몇 번 발생할 것인지를 표현하는 이산 확률 분포

# %%
 # the Poisson distribution is a limit of the Binomial distribution for rare events
sample = np.random.poisson(6 , size = 10000)
x ,y  = ecdf(sample)

_ = plt.plot(x ,y , marker = '.' , linestyle = 'none')
plt.margins(0.02)

_ = plt.xlabel('num of successes')
_ = plt.ylabel('CDF')
plt.show()

# %%
n = [20, 100, 1000]
p = [0.5, 0.1, 0.01]

for i in range(3):
    samples_binomial = np.random.binomial(n[i] ,p[i], 10000)

    print('n =', n[i], 'Binom:', np.mean(samples_binomial),
                                 np.std(samples_binomial))
# Out:
# n = 20 Binom: 10.0352 2.248679826031265
# n = 100 Binom: 10.0339 2.9896071297078484
# n = 1000 Binom: 9.9778 3.1523811888792888

# %% [markdown]
# ### Probability density functions

# %% [markdown]
# Normal distribution 두개의 매개변수로 매개변수화 된다.
# 평균 그래프의 중심이 되는곳 ,  표준편차 얼마나 넓은지 또는 데이터가 얼마나 분산되어있는지 측정

# %%
samples_std1 = np.random.normal(20, 1, size=100000)
samples_std3 = np.random.normal(20, 3, size=100000)
samples_std10 = np.random.normal(20, 10, size=100000)

# Generate CDFs
x_std1, y_std1 = ecdf(samples_std1)
x_std3, y_std3 = ecdf(samples_std3)
x_std10, y_std10 = ecdf(samples_std10)

# Plot CDFs
_ = plt.plot(x_std1, y_std1, marker='.', linestyle='none')
_ = plt.plot(x_std3, y_std3, marker='.', linestyle='none')
_ = plt.plot(x_std10, y_std10, marker='.', linestyle='none')

plt.margins(0.02)

_ = plt.legend(('std = 1', 'std = 3', 'std = 10'), loc='lower right')
plt.show()
